# %%
pip install dlib
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [47 lines of output]
#   C:\Users\jahag\AppData\Local\Temp\pip-install-a1c7h8aq\dlib_03d9016cc24941249c91b68ec839b1d0\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#     major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
#   C:\Users\jahag\AppData\Local\Temp\pip-install-a1c7h8aq\dlib_03d9016cc24941249c91b68ec839b1d0\setup.py:235: SyntaxWarning: invalid escape sequence '\('
# ...

# %%
pip install face_recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [47 lines of output]
#   C:\Users\jahag\AppData\Local\Temp\pip-install-lczmw3ku\dlib_cc676a7359a44d11a9e099edb67f9620\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#     major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
# ...

# %%
pip install face_recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [47 lines of output]
#   C:\Users\jahag\AppData\Local\Temp\pip-install-pgaqeh2n\dlib_c322b7d9a6854abdb9a108401fb90df3\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#     major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
# ...

# %%
pip uninstall opencv-python opencv-python-headless opencv-contrib-python -y
# Out:
# Found existing installation: opencv-contrib-python 4.10.0.84
# Uninstalling opencv-contrib-python-4.10.0.84:
#   Successfully uninstalled opencv-contrib-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Skipping opencv-python as it is not installed.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Skipping opencv-python-headless as it is not installed.

# %%
pip install opencv-contrib-python
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
import cv2
print("OpenCV version:", cv2.__version__)
print("Face module exists:", hasattr(cv2, "face"))
# Out:
# OpenCV version: 4.10.0
# Face module exists: True

# %%
# !pip install opencv-contrib-python==4.5.5.64
# Out:
# ...
#   Using cached opencv_contrib_python-4.5.5.64-cp36-abi3-win_amd64.whl.metadata (18 kB)
# ...
# Using cached opencv_contrib_python-4.5.5.64-cp36-abi3-win_amd64.whl (42.2 MB)
# ...
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.10.0.84
#     Uninstalling opencv-contrib-python-4.10.0.84:
#       Successfully uninstalled opencv-contrib-python-4.10.0.84
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\jahag\anaconda3\Lib\site-packages\~~2'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
import cv2
print("OpenCV version:", cv2.__version__)
print("Face module exists:", hasattr(cv2, "face"))
# Out:
# OpenCV version: 4.10.0
# Face module exists: True

# %%
pip install face_recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [47 lines of output]
#   C:\Users\jahag\AppData\Local\Temp\pip-install-rko7c1wf\dlib_913619b0ab5c44fb9d9cab87319f1200\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#     major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
# ...

# %%
pip uninstall pyttsx3 opencv-contrib-python pyserial -y
# Out:
# Found existing installation: pyttsx3 2.90
# Uninstalling pyttsx3-2.90:
#   Successfully uninstalled pyttsx3-2.90
# Found existing installation: opencv-contrib-python 4.5.5.64
# Uninstalling opencv-contrib-python-4.5.5.64:
#   Successfully uninstalled opencv-contrib-python-4.5.5.64
# Found existing installation: pyserial 3.5
# Uninstalling pyserial-3.5:
#   Successfully uninstalled pyserial-3.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip setuptools wheel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
pip install pyttsx3 opencv-contrib-python pyserial
# Out:
# ...
#   Using cached pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached pyttsx3-2.98-py3-none-any.whl (34 kB)
# Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
# Using cached pyserial-3.5-py2.py3-none-any.whl (90 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
pip install opencv-contrib-python-headless
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
pip install pyttsx3==2.90
# Out:
# ...
#   Using cached pyttsx3-2.90-py3-none-any.whl.metadata (3.6 kB)
# ...
# Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# ...
#   Attempting uninstall: pyttsx3
#     Found existing installation: pyttsx3 2.98
#     Uninstalling pyttsx3-2.98:
#       Successfully uninstalled pyttsx3-2.98
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
pip install pyserial==3.5
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# absl-py                           2.1.0
# aext-assistant                    4.0.15
# aext-assistant-server             4.0.15
# aext-core                         4.0.15
# aext-core-server                  4.0.15
# aext-panels                       4.0.15
# aext-panels-server                4.0.15
# aext-share-notebook               4.0.15
# aext-share-notebook-server        4.0.15
# aext-shared                       4.0.15
# aiobotocore                       2.12.3
# aiohttp                           3.9.5
# aiohttp-retry                     2.8.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# ...

# %%
pip install --trusted-host pypi.org --trusted-host pypi.python.org pyttsx3 opencv-contrib-python pyserial
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jahag\anaconda3\Lib\site-packages)

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
import serial
import time
import pyttsx3

# Variables for tracking
q = 1
x = 0
c = 0
m = 0
d = 0

# Initialize text-to-speech engine
def speak(audio):
    engine.say(audio)
    engine.runAndWait()

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty("voice", voices[0].id)
engine.setProperty("rate", 140)
engine.setProperty("volume", 1000)

# Training the LBPH face recognizer
while q <= 2:
    data_path = 'D:/Face_detection_for_door_lock/Samples'  # Path to training data
    onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
    Training_data, Labels = [], []

    for i, files in enumerate(onlyfiles):
        image_path = join(data_path, onlyfiles[i])
        images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        Training_data.append(np.asarray(images, dtype=np.uint8))
        Labels.append(i)

    Labels = np.asarray(Labels, dtype=np.int32)

    # Create and train the model
    model = cv2.face.LBPHFaceRecognizer_create()
    model.train(np.asarray(Training_data), np.asarray(Labels))
    print("Training complete")
    q += 1

# Load face detection model
face_classifier = cv2.CascadeClassifier('D:/Face_detection_for_door_lock/face_model.xml')

# Function to detect faces
def face_detector(img, size=0.5):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    if len(faces) == 0:
        return img, []
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
        roi = img[y:y + h, x:x + w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

# Start video capture
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    image, face = face_detector(frame)

    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
        result = model.predict(face)

        if result[1] < 500:
            confidence = int((1 - (result[1]) / 300) * 100)
            display_string = f'Confidence: {confidence}%'
            cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (0, 255, 0))

        if confidence >= 83:
            cv2.putText(image, "Unlocked", (250, 450), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (0, 255, 255))
            cv2.imshow('Face Recognition', image)
            x += 1
        else:
            cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (0, 255, 255))
            cv2.imshow('Face Recognition', image)
            c += 1
    except:
        cv2.putText(image, "Face Not Found", (250, 450), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (0, 255, 255))
        cv2.imshow('Face Recognition', image)
        d += 1
        pass

    # Exit conditions
    if cv2.waitKey(1) == 13 or x == 10 or c == 30 or d == 20:
        break

cap.release()
cv2.destroyAllWindows()

# Sending signals to the door lock
if x >= 5:
    m = 1
    try:
        ard = serial.Serial('COM3', 112500)  # Adjust COM port if needed
        time.sleep(2)
        var = 'a'
        c = var.encode()
        speak("Face recognition complete. It is matching with the database. Welcome! The door is opening for 5 seconds.")
        ard.write(c)
        time.sleep(4)
    except serial.SerialException as e:
        print(f"Error with serial communication: {e}")
elif c == 30:
    speak("Face is not matching. Please try again.")
elif d == 20:
    speak("Face is not found. Please try again.")

if m == 1:
    speak("The door is closing.")
# Out:
# Training complete
# Training complete

# %%
import cv2
print("OpenCV version:", cv2.__version__)

# Check for LBPHFaceRecognizer
print("Face module exists:", hasattr(cv2, "face"))
# Out:
# OpenCV version: 4.10.0
# Face module exists: True
